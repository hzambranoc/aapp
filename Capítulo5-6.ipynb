# %% [markdown]
# <h1>Tabla de contenidos<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Regresión" data-toc-modified-id="Regresión-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Regresión</a></span><ul class="toc-item"><li><span><a href="#Relación-entre-variables" data-toc-modified-id="Relación-entre-variables-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Relación entre variables</a></span><ul class="toc-item"><li><span><a href="#Matriz-de-dispersión" data-toc-modified-id="Matriz-de-dispersión-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Matriz de dispersión</a></span></li><li><span><a href="#Matriz-de-correlación-de-Pearson" data-toc-modified-id="Matriz-de-correlación-de-Pearson-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Matriz de correlación de Pearson</a></span></li></ul></li><li><span><a href="#Enfoque-de-Mínimos-cuadrados" data-toc-modified-id="Enfoque-de-Mínimos-cuadrados-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Enfoque de Mínimos cuadrados</a></span></li><li><span><a href="#Descenso-del-gradiente" data-toc-modified-id="Descenso-del-gradiente-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Descenso del gradiente</a></span></li><li><span><a href="#Regresión-con-Scikit-Learn" data-toc-modified-id="Regresión-con-Scikit-Learn-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Regresión con Scikit-Learn</a></span></li><li><span><a href="#Consenso-de-muestra-aleatoria-(RAMSAC)" data-toc-modified-id="Consenso-de-muestra-aleatoria-(RAMSAC)-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Consenso de muestra aleatoria (RAMSAC)</a></span></li><li><span><a href="#Regresión-polinómica" data-toc-modified-id="Regresión-polinómica-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Regresión polinómica</a></span></li><li><span><a href="#Método-algebráico" data-toc-modified-id="Método-algebráico-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Método algebráico</a></span></li><li><span><a href="#Funciones-no-lineales" data-toc-modified-id="Funciones-no-lineales-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Funciones no lineales</a></span><ul class="toc-item"><li><span><a href="#Función-cúbica" data-toc-modified-id="Función-cúbica-1.8.1"><span class="toc-item-num">1.8.1&nbsp;&nbsp;</span>Función cúbica</a></span></li><li><span><a href="#Función-cuadrática" data-toc-modified-id="Función-cuadrática-1.8.2"><span class="toc-item-num">1.8.2&nbsp;&nbsp;</span>Función cuadrática</a></span></li><li><span><a href="#Función-exponencial" data-toc-modified-id="Función-exponencial-1.8.3"><span class="toc-item-num">1.8.3&nbsp;&nbsp;</span>Función exponencial</a></span></li><li><span><a href="#Función-logaritmica" data-toc-modified-id="Función-logaritmica-1.8.4"><span class="toc-item-num">1.8.4&nbsp;&nbsp;</span>Función logaritmica</a></span></li><li><span><a href="#Función-logistica/sigmoide" data-toc-modified-id="Función-logistica/sigmoide-1.8.5"><span class="toc-item-num">1.8.5&nbsp;&nbsp;</span>Función logistica/sigmoide</a></span></li><li><span><a href="#Ejemplo-suscripciones-de-telefonía" data-toc-modified-id="Ejemplo-suscripciones-de-telefonía-1.8.6"><span class="toc-item-num">1.8.6&nbsp;&nbsp;</span>Ejemplo suscripciones de telefonía</a></span></li></ul></li><li><span><a href="#Regularización" data-toc-modified-id="Regularización-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Regularización</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Regresión-Rígida" data-toc-modified-id="Regresión-Rígida-1.9.0.1"><span class="toc-item-num">1.9.0.1&nbsp;&nbsp;</span>Regresión Rígida</a></span></li><li><span><a href="#Regresión-Lasso" data-toc-modified-id="Regresión-Lasso-1.9.0.2"><span class="toc-item-num">1.9.0.2&nbsp;&nbsp;</span>Regresión Lasso</a></span></li><li><span><a href="#Red-elástica" data-toc-modified-id="Red-elástica-1.9.0.3"><span class="toc-item-num">1.9.0.3&nbsp;&nbsp;</span>Red elástica</a></span></li></ul></li></ul></li><li><span><a href="#Métricas-y-técnicas-de-validación" data-toc-modified-id="Métricas-y-técnicas-de-validación-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Métricas y técnicas de validación</a></span><ul class="toc-item"><li><span><a href="#Método-train_test_split()" data-toc-modified-id="Método-train_test_split()-1.10.1"><span class="toc-item-num">1.10.1&nbsp;&nbsp;</span>Método train_test_split()</a></span></li><li><span><a href="#Error-absoluto-medio-(MAE)" data-toc-modified-id="Error-absoluto-medio-(MAE)-1.10.2"><span class="toc-item-num">1.10.2&nbsp;&nbsp;</span>Error absoluto medio (MAE)</a></span></li><li><span><a href="#Error-cuadrático-medio-(MSE)" data-toc-modified-id="Error-cuadrático-medio-(MSE)-1.10.3"><span class="toc-item-num">1.10.3&nbsp;&nbsp;</span>Error cuadrático medio (MSE)</a></span></li><li><span><a href="#Coeficiente-de-determinación-(R2)" data-toc-modified-id="Coeficiente-de-determinación-(R2)-1.10.4"><span class="toc-item-num">1.10.4&nbsp;&nbsp;</span>Coeficiente de determinación (R2)</a></span></li><li><span><a href="#Validación-cruzada-por-k-iteraciones" data-toc-modified-id="Validación-cruzada-por-k-iteraciones-1.10.5"><span class="toc-item-num">1.10.5&nbsp;&nbsp;</span>Validación cruzada por k iteraciones</a></span></li></ul></li><li><span><a href="#Curvas-de-validación-y-aprendizaje" data-toc-modified-id="Curvas-de-validación-y-aprendizaje-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Curvas de validación y aprendizaje</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Curvas-de-validación" data-toc-modified-id="Curvas-de-validación-1.11.0.1"><span class="toc-item-num">1.11.0.1&nbsp;&nbsp;</span>Curvas de validación</a></span></li><li><span><a href="#Curvas-de-aprendizaje" data-toc-modified-id="Curvas-de-aprendizaje-1.11.0.2"><span class="toc-item-num">1.11.0.2&nbsp;&nbsp;</span>Curvas de aprendizaje</a></span></li></ul></li></ul></li><li><span><a href="#Búsqueda-de-cuadrículas" data-toc-modified-id="Búsqueda-de-cuadrículas-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Búsqueda de cuadrículas</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Regresión

# %% [markdown]
# ## Relación entre variables

# %% [markdown]
# ### Matriz de dispersión

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy as np
df = pd.read_csv("precios_casas.csv")

# %%
cols = ['bedrooms','bathrooms','sqft_living','sqft_lot','price']
sb.pairplot(df[cols] , height=2.5)
plt.tight_layout()
plt.show()
# Out:
# /home/hzambrano/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /tmp/ipykernel_19399/2932942880.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ### Matriz de correlación de Pearson

# %%
cm = np.corrcoef(df[cols].values.T)
sb.set(font_scale=1.5)
hm = sb.heatmap(cm, cbar=True, 
                annot=True,
                square=True,
                fmt='.2f',
                annot_kws={'size':15},
                yticklabels=cols,
                xticklabels=cols                
                )
plt.show()

# %% [markdown]
# ## Enfoque de Mínimos cuadrados

# %%
X = df.iloc[0:10,3].values
y = df.iloc[0:10,0].values

mms_x = MinMaxScaler()
mms_y = MinMaxScaler()
X_std = mms_x.fit_transform(X.reshape(-1,1))
y_std = mms_y.fit_transform(y.reshape(-1,1))

# %%
y_p1 = X_std - 2
y_p2 = 2*X_std + 5
y_p3 = 0.1*X_std + 0.05

fig, axs = plt.subplots(1,3, figsize=(15,4)) 
axs[0].scatter(X_std, y_std,  color='orange')
axs[0].plot(X_std, y_p1 , color='black')
axs[0].set_title('y = X - 2')

axs[1].scatter(X_std, y_std ,  color='gray')
axs[1].plot(X_std, y_p2, color='black')
axs[1].set_title('y = 2*X + 5')

axs[2].scatter(X_std, y_std ,  color='green')
axs[2].plot(X_std, y_p3, color='black')
axs[2].set_title('y = 0.1*X + 0.05')
plt.show()

# %% [markdown]
# ## Descenso del gradiente

# %%
X = df[['sqft_living']].values[:10]
y = df['price'].values[:10]
w = [0.1 ,0.5]
num_epocas = 1

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
X = sc_x.fit_transform(X)
y = sc_y.fit_transform(y[:, np.newaxis]).flatten()

# %%
# Este método calcula un valor para y basado en los pesos
def calcular_prediccion(x, w):      
    prediccion = np.dot(x, w[1:]) + w[0]
    return prediccion

# Este método permite calcular los valores de J
def calcular_costo(X, y):
    m = len(X)
    error = 0.0
    prediccion = calcular_prediccion(X, w)
    error = (y - prediccion)
    costo = (error ** 2).sum() / 2    
    return costo

# Este método implementa el algoritmo del descenso del gradiente
def entrenar(X, y, w,  max_iter, tasa_aprendizaje): 
    costos = []
    m = len(X)
    for i in range(max_iter):          
        prediccion = calcular_prediccion(X, w)  
        error = (y - prediccion)                   
        w[0] += 2 * tasa_aprendizaje * error.sum() 
        w[1:] += 2 * tasa_aprendizaje * np.dot(X.T,error) 
        costo = calcular_costo(X, y)        
        costos.append(costo)                                  
    return w, costos

# %%
w = [0.1 ,0.5]
w , costos = entrenar(X, y, w, max_iter=num_epocas, tasa_aprendizaje=0.001)
print('w0: {:.3f}'.format(w[0]))
print('w1: {:.3f}'.format(w[1]))
# Out:
# w0: 0.098
# w1: 0.505

# %%
plt.scatter(X, y, c='blue', edgecolor='white', s=70)
plt.plot(X, calcular_prediccion(X,w), color='black', lw=2)    
plt.xlabel('sqtf_living')
plt.ylabel('price')
plt.show()

# %%
plt.plot(range(1, num_epocas + 1), costos)
plt.ylabel('Función de costo (J)')
plt.xlabel('Épocas')
plt.show()

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(max_iter=1000, tol=1e-3, eta0=0.001, random_state=1)
sgd_reg.fit(X, y)
# Out:
# SGDRegressor(eta0=0.001, random_state=1)

# %%
w0, w1 = sgd_reg.intercept_, sgd_reg.coef_
print("w0:" , w0)
print("w1:", w1)
# Out:
# w0: [0.00017709]
# w1: [0.08539101]

# %% [markdown]
# ## Regresión con Scikit-Learn

# %% [markdown]
# **Regresión lineal simple:**

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
# se obtienen las primeras 10 instancias
X = df[['sqft_living']].values[:10]
y = df['price'].values[:10]
# se estandarizan las variables
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
X_esc = sc_x.fit_transform(X)
y_esc = sc_y.fit_transform(y[:, np.newaxis]).flatten()

reg.fit(X_esc, y_esc)
print('w0: {:.3f}'.format(reg.intercept_))
print('w1: {:.3f}'.format(reg.coef_[0]))
# Out:
# w0: 0.000
# w1: 0.737

# %%
sqtf_living = sc_x.transform(np.array([[10000]]))
precio = reg.predict(sqtf_living)
print('Precio predicho: %.3f' % precio )
# Out:
# Precio predicho: 7.794

# %% [markdown]
# **Regresión múltiple**

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
# se obtienen los arreglos X e y
X = df[['bedrooms','bathrooms','sqft_living','sqft_lot']].values
y = df['price'].values
# se estandarizan las variables
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
X = sc_x.fit_transform(X)
y = sc_y.fit_transform(y[:, np.newaxis]).flatten()
# se separa el dataset en conjunto de entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=0.3, random_state=1)
# ajustamos el modelo con los datos de entrenamiento
reg.fit(X_ent, y_ent)
print('intercepto: {:.3f}'.format(reg.intercept_))
print('coeficientes: ' , reg.coef_)
# calculamos la exactitud del modelo
print('Exactitud: {:.3f}'.format(reg.score(X_pru, y_pru)))
# Out:
# intercepto: 0.009
# coeficientes:  [-0.09001078  0.00709681  0.49100858 -0.05325143]
# Exactitud: 0.428

# %% [markdown]
# ## Consenso de muestra aleatoria (RAMSAC)

# %%
from sklearn.linear_model import RANSACRegressor

ransac = RANSACRegressor(reg)
ransac.fit(X_esc,y_esc)
print("w0: %.3f" % ransac.estimator_.intercept_)
print("w1: %.3f" % ransac.estimator_.coef_)
# Out:
# w0: -0.422
# w1: 0.152

# %%
X_esc.shape
# Out:
# (10, 1)

# %%
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)

line_X = np.arange(X_esc.min(), X_esc.max())[:, np.newaxis]
line_y = reg.predict(line_X)
line_y_ransac = ransac.predict(line_X)

lw = 2
plt.scatter(X_esc[inlier_mask], y_esc[inlier_mask], color='yellowgreen', marker='.',
            label='Inliers')
plt.scatter(X_esc[outlier_mask], y_esc[outlier_mask], color='gold', marker='.',
            label='Outliers')
plt.plot(line_X, line_y, color='navy', linewidth=lw, label='Regresor Lineal')
plt.plot(line_X, line_y_ransac, color='cornflowerblue', linewidth=lw, label='Regresor RANSAC')
plt.legend(loc='upper left')
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## Regresión polinómica

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X_esc, y_esc, test_size=0.3 , random_state=50)

poly = PolynomialFeatures(degree=2)
X_ent_poly = poly.fit_transform(X_ent)
X_pru_poly = poly.fit_transform(X_pru)
X_ent_poly
# Out:
# array([[ 1.00000000e+00, -5.93099559e-02,  3.51767087e-03],
#        [ 1.00000000e+00, -4.61299657e-02,  2.12797373e-03],
#        [ 1.00000000e+00,  2.20764836e+00,  4.87371127e+00],
#        [ 1.00000000e+00, -1.44320893e+00,  2.08285201e+00],
#        [ 1.00000000e+00,  3.29499755e-02,  1.08570089e-03],
#        [ 1.00000000e+00, -5.99689554e-01,  3.59627561e-01],
#        [ 1.00000000e+00, -8.36929378e-01,  7.00450783e-01]])

# %%
reg = LinearRegression()
reg.fit(X_ent_poly, y_ent)
# Coeficientes
print ('Coeficientes: ', reg.coef_)
print ('Intercepto: ',reg.intercept_)
# Out:
# Coeficientes:  [0.         0.54382876 0.40900654]
# Intercepto:  -0.2525610327311757

# %%
x_fit = np.arange(X_ent.min(), X_ent.max(), 1)[: , np.newaxis]
y_p = reg.predict(poly.fit_transform(x_fit))
plt.scatter(X_ent, y_ent, label='Puntos de entrenamiento')
plt.plot(x_fit, y_p)
plt.legend(loc='upper left')
plt.show()
print('Precisión del modelo: {:.2f}'.format(reg.score(X_ent_poly, y_ent)))
# Out:
# Precisión del modelo: 0.97

# %% [markdown]
# ## Método algebráico

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("precios_casas.csv")

X = df[['sqft_living']].values
y = df['price'].values
w = np.zeros(X.shape[1])

from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
X = sc_x.fit_transform(X)
y = sc_y.fit_transform(y[:, np.newaxis]).flatten()

# adicionamos una columna de unos 
X2 = np.hstack((np.ones((X.shape[0], 1)), X))

t1 = np.linalg.inv(np.dot(X2.T, X2)) 
t2 = np.dot(X2.T , y)
w = np.dot(t1 , t2)
print("w0 : {:.3f}".format(w[0]))
print("w1 : {:.3f}".format(w[1]))
# Out:
# w0 : 0.000
# w1 : 0.430

# %% [markdown]
# ## Funciones no lineales

# %% [markdown]
# ### Función cúbica

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = 1*(x**3) + 1*(x**2) + 1*x + 1
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Variable dependiente')
plt.xlabel('Variable independiente')
plt.show()

# %% [markdown]
# ### Función cuadrática

# %%
x = np.arange(-5.0, 5.0, 0.1)
y = np.power(x,2)
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Variable dependiente')
plt.xlabel('Variable independiente')
plt.show()

# %% [markdown]
# ### Función exponencial

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y= np.exp(X)
plt.plot(X,Y) 
plt.ylabel('Variable dependiente')
plt.xlabel('Variable independiente')
plt.show()

# %% [markdown]
# ### Función logaritmica

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = np.log(X)
plt.plot(X,Y) 
plt.ylabel('Variable dependiente')
plt.xlabel('Variable independiente')
plt.show()
# Out:
# C:\Users\Carlos pineda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %% [markdown]
# ### Función logistica/sigmoide

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = 1.0 / (1.0 + np.exp(-X))
plt.plot(X,Y) 
plt.ylabel('Variable dependiente')
plt.xlabel('Variable independiente')
plt.show()

# %% [markdown]
# ### Ejemplo suscripciones de telefonía

# %%
df2 = pd.read_csv("datos_suscripciones.csv")
df2.sample(5)
# Out:
#        año      cantidad
# 12  1972.0      0.000000
# 9   1969.0      0.000000
# 59  2019.0  16209.380705
# 38  1998.0   1637.138619
# 35  1995.0    474.552050

# %%
plt.scatter(df2['año'] , df2['cantidad'], color='r')
plt.xlabel("Año")
plt.xlim(1960, 2020)
plt.ylabel("Suscripciones")
plt.show()

# %%
def sigmoid(x, beta1, beta2):
     y = 1 / (1 + np.exp(-beta1*(x-beta2)))
     return y

# %%
# normalicemos los datos
xdata =df2['año']/max(df2['año'])
ydata =df2['cantidad']/max(df2['cantidad'])

from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid, xdata, ydata)
print(" beta1: {:.2f}, beta2: {:.2f}".format(popt[0], popt[1]))
# Out:
#  beta1: 696.54, beta2: 0.99

# %%
beta_1 = 0.3
beta_2 = 2000.0
Y_pred = sigmoid(df2['año'], beta_1 , beta_2)
plt.plot(df2['año'], Y_pred*26800 , 'g')
plt.plot(df2['año'], df2['cantidad'], 'ro')
plt.xlim(1960, 2020)
plt.xlabel("Año")
plt.ylabel("Suscripciones")
# Out:
# Text(0, 0.5, 'Suscripciones')

# %%
x = np.linspace(1960, 2020, 55)
x = x/max(x)
plt.figure(figsize=(8,5))
y = sigmoid(x, *popt)
plt.plot(xdata, ydata, 'ro', label='datos')
plt.plot(x,y, linewidth=3.0, label='ajuste')
plt.ylabel('Suscripciones')
plt.xlabel('Año')
plt.show()

# %%
X=xdata
y=ydata
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(xdata,ydata, test_size=0.2, random_state=1)
# crear el modelo
popt, pcov = curve_fit(sigmoid, x_train, y_train)
# predicciones sobre el dataset de test
y_hat = sigmoid(x_test, *popt)
# Evaluacion
from sklearn.metrics import r2_score
print("R2: {:.2f}".format(r2_score(y_hat , y_test) ))
# Out:
# R2: 1.00

# %% [markdown]
# ## Regularización

# %% [markdown]
# #### Regresión Rígida

# %%
from sklearn.linear_model import Ridge
rig = Ridge(alpha=10)

X = df[['bedrooms','bathrooms','sqft_living','sqft_lot']].values
y = df['price'].values
# se estandarizan las variables
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
X = sc_x.fit_transform(X)
y = sc_y.fit_transform(y[:, np.newaxis]).flatten()

# %%
X_ent, X_pru, y_ent, y_pru = train_test_split(X,y, test_size=0.3, random_state=1)

modelo = rig.fit(X_ent , y_ent)
print("Coeficientes: " , modelo.coef_)
print('R2: {:.3f}'.format(modelo.score(X_pru, y_pru)))
# Out:
# Coeficientes:  [-0.08844316  0.00950749  0.48659172 -0.05238501]
# R2: 0.428

# %%
plt.plot(rig.coef_, 'r-' , label='Coeficientes Ridge')
plt.plot(reg.coef_,'b*',label='Coeficientes OLS')
plt.legend()
plt.xlabel('Coeficiente')
plt.show()

# %%
from sklearn.linear_model import RidgeCV
reg = RidgeCV(alphas=[0.01, 0.1 , 1.0 , 10.0, 20.0, 50.0 , 100.0] )
modelo = reg.fit(X , y)
print("Coeficientes: " , modelo.coef_)
print("Valor alfa: " , modelo.alpha_)
# Out:
# Coeficientes:  [-0.09009378  0.01665267  0.47888413 -0.04576882]
# Valor alfa:  20.0

# %% [markdown]
# #### Regresión Lasso

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.1)
modelo = lasso.fit(X_ent , y_ent)
print("Coeficientes: " , modelo.coef_)
print('R2 Lasso: {:.3f}'.format(modelo.score(X_pru, y_pru)))
# Out:
# Coeficientes:  [ 0.          0.          0.33414394 -0.        ]
# R2 Lasso: 0.391

# %%
plt.plot(lasso.coef_, 'r-' , label='Coeficientes Lasso')
plt.plot(reg.coef_,'b*',label='Coeficientes OLS')
plt.legend()
plt.xlabel('Coeficiente')
plt.show()

# %% [markdown]
# #### Red elástica

# %%
from sklearn.linear_model import ElasticNet
modelo = ElasticNet(alpha=0.1, l1_ratio=1)
modelo = reg.fit(X_ent , y_ent)
print("Coeficientes: " , modelo.coef_)
print('R2 Lasso: {:.3f}'.format(lasso.score(X_pru, y_pru)))
# Out:
# Coeficientes:  [-0.08690568  0.01183956  0.4822829  -0.05153964]
# R2 Lasso: 0.391

# %% [markdown]
# ## Métricas y técnicas de validación

# %% [markdown]
# ### Método train_test_split()

# %%
from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=0.3)
y_pred = reg.predict(X_pru)

# %% [markdown]
# ### Error absoluto medio (MAE)

# %%
from sklearn.metrics import mean_absolute_error
mae_pru = mean_absolute_error(y_pru,y_pred )
print("error absoluto medio: {:.2f}".format(mae_pru))
# Out:
# error absoluto medio: 0.36

# %% [markdown]
# ### Error cuadrático medio (MSE)

# %%
from sklearn.metrics import mean_squared_error
mse_pru = mean_squared_error(y_pru,y_pred)
print("error cuadrático medio: {:.2f}".format(mse_pru))
# Out:
# error cuadrático medio: 2.15

# %% [markdown]
# ### Coeficiente de determinación (R2)

# %%
from sklearn.metrics import r2_score
r2_pru = r2_score(y_pru,y_pred)           
print("coeficiente R2: {:.2f}".format(r2_pru))
# Out:
# coeficiente R2: 0.07

# %% [markdown]
# ### Validación cruzada por k iteraciones

# %%
from sklearn.model_selection import cross_val_score

X = df[['sqft_living']].values
y = df['price'].values

vals = cross_val_score(reg, # modelo
                       X, # atributos descriptivos
                       y, # atributo destino
                       cv=5 # k (cantidad de subconjuntos)                       
                       )
print("Valores validación cruzada: %s " % vals)
print("Media: {:.3f} Desviación estándar: {:.3f}".format(np.mean(vals) , np.std(vals) ) )
# Out:
# Valores validación cruzada: [0.49431685 0.49246653 0.51222566 0.50080368 0.01756059]
# Media: 0.403 Desviación estándar: 0.193

# %% [markdown]
# ## Curvas de validación y aprendizaje

# %% [markdown]
# #### Curvas de validación

# %%
df3 = pd.read_csv("emisiones2.csv")
plt.scatter(df3['anio'] , df3['cantidad'], color='r')
plt.xlabel("año")
plt.xlim(1965, 2010)
plt.ylabel("emisión")
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
X_test = np.arange(1970, 2020, 1)
X = df3['anio'].values.reshape(-1,1) 
y =  df3['cantidad'].values.reshape(-1,1) 
plt.scatter(X, y, color='black')

for grado in [1, 3, 6, 10]:
    poli = PolynomialFeatures(degree = grado )
    X_p = poli.fit_transform(X)    
    modelo = LinearRegression().fit(X_p, y)
    to_predict = poli.fit_transform(X_test.reshape(-1,1))
    y_pred = modelo.predict(to_predict).reshape(1,50)[0]    
    plt.plot(X_test, y_pred, label='Grado={0}'.format(grado))
plt.legend(loc='best');
plt.xlabel("año")
plt.xlim(1965, 2010)
plt.ylabel("emisión")
# Out:
# Text(0, 0.5, 'emisión')

# %%
from sklearn.model_selection import validation_curve
from sklearn.pipeline import Pipeline

from sklearn.model_selection import train_test_split
X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=0.1, random_state=1)

grados =  [1, 2, 3, 6, 8, 10, 20]
# creamos un pipeline para encadenar el trabajo con PolynomialFeatures y  LinearRegression
pipe = Pipeline([('scaler', StandardScaler()) ,('poly', PolynomialFeatures(degree=2)), 
                       ('regl', LinearRegression())])
train_scores, test_scores = validation_curve(pipe, X_ent,  y_ent,
                                      'poly__degree', grados, cv=10)

# %%
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(grados, train_mean, 
         color='blue', marker='o', 
         markersize=5, label='Exactitud entrenamiento')

plt.fill_between(grados, train_mean + train_std,
                 train_mean - train_std, alpha=0.15,
                 color='blue')

plt.plot(grados, test_mean, 
         color='green', linestyle='--', 
         marker='s', markersize=5, 
         label='Exaxtitud validación')

plt.fill_between(grados, 
                 test_mean + test_std,
                 test_mean - test_std, 
                 alpha=0.15, color='green')
plt.legend(loc='best')
plt.ylim(-1, 1)
plt.xlabel('Grado')
plt.ylabel('Puntaje');

# %%
plt.scatter(X_ent.ravel(), y_ent)
lim = plt.axis()
pipe = Pipeline([('scaler', StandardScaler()), ('poly', PolynomialFeatures(degree=10)),
                       ('regl', LinearRegression())])
y_test = pipe.fit(X_ent, y_ent).predict(X_test.reshape(-1,1))
plt.plot(X_test.ravel(), y_test);
plt.axis(lim);
plt.xlabel("año")
plt.xlim(1965, 2010)
plt.ylabel("emisión")
# Out:
# C:\Users\Carlos pineda\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Text(0, 0.5, 'emisión')

# %% [markdown]
# #### Curvas de aprendizaje

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, test_scores = learning_curve(estimator=pipe,
                               X=X_ent,
                               y=y_ent,
                               train_sizes=np.linspace(0.1, 1.0, 10),
                               cv=10,
                               n_jobs=1)

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean,
         color='blue', marker='o',
         markersize=5, label='Exactitud entrenamiento')

plt.fill_between(train_sizes,
                 train_mean + train_std,
                 train_mean - train_std,
                 alpha=0.15, color='blue')

plt.plot(train_sizes, test_mean,
         color='green', linestyle='--',
         marker='s', markersize=5,
         label='Exactitud validación')

plt.fill_between(train_sizes,
                 test_mean + test_std,
                 test_mean - test_std,
                 alpha=0.15, color='green')

plt.grid()
plt.xlabel('Numero de muestras de entrenamiento')
plt.ylabel('Exactitud')
plt.legend(loc='lower right')
plt.ylim([-0.5, 1.1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Búsqueda de cuadrículas

# %%
from sklearn.model_selection import GridSearchCV
model = Pipeline([('scaler', StandardScaler()), ('poly', PolynomialFeatures()),
                       ('regl', LinearRegression())])

parms = {'poly__degree': np.arange(2, 20)}

gscv = GridSearchCV(model, parms, cv = 10, scoring='neg_mean_squared_error')
gscv.fit(X_ent.reshape(-1,1),y_ent)

space = np.linspace(1970,2008,50).reshape(-1,1)

est_deg= gscv.best_params_['poly__degree']

plt.scatter(X_ent.ravel(), y_ent)
plt.plot(space, gscv.predict(space), color = 'red')
plt.title(f'Grado estimado:{est_deg}')
plt.xlabel("año")
plt.xlim(1965, 2010)
plt.ylabel("emisión")
# Out:
# C:\Users\Carlos pineda\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:842: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Text(0, 0.5, 'emisión')
